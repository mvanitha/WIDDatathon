# %%
import os
import pandas as pd
import numpy as py
from pandas_profiling import ProfileReport
import seaborn as sns

# %%
folder = os.getcwd() +r"/Data Files"
odata = pd.read_csv(folder +r"/COVID19 Hackathon Dataset.csv")
odata.head(5)
# Out:
#          Date Continent    Countries  New_Cases  New_Deaths  Total_Cases  \
# 0  2019-12-31      Asia  Afghanistan        0.0         0.0          0.0
# 1  2020-01-01      Asia  Afghanistan        0.0         0.0          0.0
# 2  2020-01-02      Asia  Afghanistan        0.0         0.0          0.0
# 3  2020-01-03      Asia  Afghanistan        0.0         0.0          0.0
# 4  2020-01-04      Asia  Afghanistan        0.0         0.0          0.0
#
#    Total_Deaths  Weekly_Cases  Weekly_Deaths  Population_Density  ...  \
# 0           0.0           NaN            NaN                59.6  ...
# 1           0.0           NaN            NaN                59.6  ...
# 2           0.0           NaN            NaN                59.6  ...
# 3           0.0           NaN            NaN                59.6  ...
# 4           0.0           NaN            NaN                59.6  ...
#
#    Diabetes Prevelance % of Population 20-79  Labour Force Total  Population  \
# 0                                        9.2          10699797.0  38041754.0
# 1                                        9.2          10699797.0  38041754.0
# 2                                        9.2          10699797.0  38041754.0
# 3                                        9.2          10699797.0  38041754.0
# 4                                        9.2          10699797.0  38041754.0
#
#    Population Aged 65 and above % of Total  Urban Population  \
# 0                                 2.615794         9797273.0
# 1                                 2.615794         9797273.0
# 2                                 2.615794         9797273.0
# 3                                 2.615794         9797273.0
# 4                                 2.615794         9797273.0
#
#    Death Rate Per 1000 (2017)  \
# 0                       6.575
# 1                       6.575
# 2                       6.575
# 3                       6.575
# 4                       6.575
#
#    PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) (2017)  \
# 0                                          56.910808
# 1                                          56.910808
# 2                                          56.910808
# 3                                          56.910808
# 4                                          56.910808
#
#    PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)  \
# 0                                              100.0
# 1                                              100.0
# 2                                              100.0
# 3                                              100.0
# 4                                              100.0
#
#    Hospital Beds Year  Hospital Beds Per 1000 People
# 0              2015.0                            0.5
# 1              2015.0                            0.5
# 2              2015.0                            0.5
# 3              2015.0                            0.5
# 4              2015.0                            0.5
#
# [5 rows x 37 columns]

# %%
odata.describe()
# Out:
#           New_Cases    New_Deaths   Total_Cases   Total_Deaths   Weekly_Cases  \
# count  41506.000000  41506.000000  4.150600e+04   41506.000000   40840.000000
# mean     861.190430     25.197393  6.416093e+04    2497.838457    5974.403844
# std     4912.421116    134.616653  3.797422e+05   12420.394436   33641.343934
# min    -8261.000000  -1918.000000  0.000000e+00       0.000000   -3864.000000
# 25%        0.000000      0.000000  1.070000e+02       1.000000      11.000000
# 50%       19.000000      0.000000  1.786500e+03      35.000000     172.000000
# 75%      232.000000      4.000000  1.670800e+04     339.000000    1680.250000
# max    97894.000000   4928.000000  7.501612e+06  210909.000000  652390.000000
#
#        Weekly_Deaths  Population_Density  Fertility_Rate        GDP_PPP  \
# count   40840.000000        41782.000000    40397.000000   41570.000000
# mean      176.669956          404.073928        2.561276   21688.276305
# std       868.522808         2255.075253        1.197593   21277.864357
# min     -1625.000000            2.110000        1.230000     628.000000
# 25%         0.000000           36.200000        1.710000    5020.000000
# 50%         2.000000           92.600000        2.010000   14100.000000
# 75%        29.000000          223.000000        3.120000   33500.000000
# max     19006.000000        26300.000000        7.000000  116000.000000
#
#          Corruption  ...  Diabetes Prevelance % of Population 20-79  \
# count  41011.000000  ...                               40209.000000
# mean      -0.003089  ...                                   7.666214
# std        1.036510  ...                                   3.862255
# min       -1.800085  ...                                   1.000000
# 25%       -0.790734  ...                                   5.100000
# 50%       -0.216403  ...                                   6.600000
# 75%        0.639966  ...                                   9.600000
# max        2.212430  ...                                  22.100000
#
#        Labour Force Total    Population  \
# count        3.898800e+04  4.000900e+04
# mean         2.318639e+07  4.991501e+07
# std          8.020215e+07  1.675493e+08
# min          5.667600e+04  7.180800e+04
# 25%          2.032911e+06  3.301000e+06
# 50%          5.036882e+06  1.066971e+07
# 75%          1.555595e+07  3.647177e+07
# max          7.810746e+08  1.397715e+09
#
#        Population Aged 65 and above % of Total  Urban Population  \
# count                             39596.000000      4.000900e+04
# mean                                  9.577075      2.800517e+07
# std                                   6.643959      8.612454e+07
# min                                   1.156549      2.380000e+04
# 25%                                   3.544727      2.186104e+06
# 50%                                   7.300455      6.084994e+06
# 75%                                  15.200841      2.184476e+07
# max                                  28.002049      8.429340e+08
#
#        Death Rate Per 1000 (2017)  \
# count                39796.000000
# mean                     7.741435
# std                      2.770453
# min                      1.169000
# 25%                      5.845000
# 50%                      7.277000
# 75%                      9.498000
# max                     15.500000
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) (2017)  \
# count                                       40209.000000
# mean                                           28.110566
# std                                            19.864664
# min                                             5.861331
# 25%                                            14.611340
# 50%                                            22.196055
# 75%                                            37.926503
# max                                            99.734374
#
#        PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)  \
# count                                       40209.000000
# mean                                           87.504096
# std                                            28.563140
# min                                             0.000000
# 25%                                            96.370659
# 50%                                           100.000000
# 75%                                           100.000000
# max                                           100.000000
#
#        Hospital Beds Year  Hospital Beds Per 1000 People
# count        40209.000000                   40209.000000
# mean          2012.472034                       2.925681
# std              2.367630                       2.388715
# min           2004.000000                       0.100000
# 25%           2011.000000                       1.200000
# 50%           2013.000000                       2.300000
# 75%           2014.000000                       4.000000
# max           2015.000000                      13.400000
#
# [8 rows x 32 columns]

# %%
odata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41782 entries, 0 to 41781
# Data columns (total 37 columns):
#  #   Column                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                               --------------  -----
#  0   Date                                                                                                 41782 non-null  object
#  1   Continent                                                                                            41782 non-null  object
#  2   Countries                                                                                            41782 non-null  object
#  3   New_Cases                                                                                            41506 non-null  float64
#  4   New_Deaths                                                                                           41506 non-null  float64
#  5   Total_Cases                                                                                          41506 non-null  float64
#  6   Total_Deaths                                                                                         41506 non-null  float64
#  7   Weekly_Cases                                                                                         40840 non-null  float64
#  8   Weekly_Deaths                                                                                        40840 non-null  float64
#  9   Population_Density                                                                                   41782 non-null  float64
#  10  Fertility_Rate                                                                                       40397 non-null  float64
#  11  GDP_PPP                                                                                              41570 non-null  float64
#  12  Corruption                                                                                           41011 non-null  float64
#  13  Government_Effectiveness                                                                             41011 non-null  float64
#  14  Political_Stability                                                                                  41575 non-null  float64
#  15  Rule_of_Law                                                                                          41011 non-null  float64
#  16  Government_Healthcare_Spend                                                                          39733 non-null  float64
#  17  Urban_Population                                                                                     28470 non-null  float64
#  18  Smoking_Prevalence                                                                                   32960 non-null  float64
#  19  Tourism                                                                                              34569 non-null  float64
#  20  Women_In_Parliament                                                                                  41152 non-null  float64
#  21  Obesity_Rate                                                                                         40791 non-null  float64
#  22  RunTot_New_Cases                                                                                     41782 non-null  int64
#  23  RunTot_New_Deaths                                                                                    41782 non-null  int64
#  24  Country                                                                                              40209 non-null  object
#  25  Country Code                                                                                         40209 non-null  object
#  26  Year                                                                                                 40209 non-null  float64
#  27  Diabetes Prevelance % of Population 20-79                                                            40209 non-null  float64
#  28  Labour Force Total                                                                                   38988 non-null  float64
#  29  Population                                                                                           40009 non-null  float64
#  30  Population Aged 65 and above % of Total                                                              39596 non-null  float64
#  31  Urban Population                                                                                     40009 non-null  float64
#  32  Death Rate Per 1000 (2017)                                                                           39796 non-null  float64
#  33  PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) (2017)                        40209 non-null  float64
#  34  PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)  40209 non-null  float64
#  35  Hospital Beds Year                                                                                   40209 non-null  float64
#  36  Hospital Beds Per 1000 People                                                                        40209 non-null  float64
# dtypes: float64(30), int64(2), object(5)
# memory usage: 11.8+ MB

# %%
for col in odata.columns:
    print(col, len(set(odata[col])))
# float values are coming back weird
# Out:
# Date 282
# Continent 6
# Countries 180
# New_Cases 4344
# New_Deaths 1169
# Total_Cases 17922
# Total_Deaths 6248
# Weekly_Cases 9951
# Weekly_Deaths 3089
# Population_Density 165
# Fertility_Rate 1519
# GDP_PPP 379
# Corruption 948
# Government_Effectiveness 947
# Political_Stability 386
# Rule_of_Law 948
# Government_Healthcare_Spend 2219
# Urban_Population 13415
# Smoking_Prevalence 8937
# Tourism 7358
# Women_In_Parliament 794
# Obesity_Rate 1121
# RunTot_New_Cases 17646
# RunTot_New_Deaths 5972
# Country 174
# Country Code 174
# Year 1574
# Diabetes Prevelance % of Population 20-79 1656
# Labour Force Total 2961
# Population 1945
# Population Aged 65 and above % of Total 2356
# Urban Population 1945
# Death Rate Per 1000 (2017) 2147
# PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) (2017) 1746
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017) 1633
# Hospital Beds Year 1585
# Hospital Beds Per 1000 People 1638

# %% [markdown]
# # Countries missing additional data

# %%
# Countries missing additional data
set(odata[(odata['Countries']!=odata['Country'])]['Countries'])
# Out:
# {'Liechtenstein',
#  'Monaco',
#  'Palestine',
#  'Papua New Guinea',
#  'San Marino',
#  'South Sudan',
#  'St. Kitts and Nevis'}

# %% [markdown]
# # Clean data

# %%
data = odata.copy()
data = data\
        .drop(columns={'Country','Country Code',})\
        .rename(columns={'Countries':'Country'})
data[['Year']]
list(data)
# Out:
# ['Date',
#  'Continent',
#  'Country',
#  'New_Cases',
#  'New_Deaths',
#  'Total_Cases',
#  'Total_Deaths',
#  'Weekly_Cases',
#  'Weekly_Deaths',
#  'Population_Density',
#  'Fertility_Rate',
#  'GDP_PPP',
#  'Corruption',
#  'Government_Effectiveness',
#  'Political_Stability',
#  'Rule_of_Law',
#  'Government_Healthcare_Spend',
#  'Urban_Population',
#  'Smoking_Prevalence',
#  'Tourism',
#  'Women_In_Parliament',
#  'Obesity_Rate',
#  'RunTot_New_Cases',
#  'RunTot_New_Deaths',
#  'Year',
#  'Diabetes Prevelance % of Population 20-79',
#  'Labour Force Total',
#  'Population',
#  'Population Aged 65 and above % of Total',
#  'Urban Population',
#  'Death Rate Per 1000 (2017)',
#  'PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) (2017)',
#  'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)',
#  'Hospital Beds Year',
#  'Hospital Beds Per 1000 People']

# %% [markdown]
# # Hospital beds

# %%
# Hospital Beds
hosp = data[['Country','Hospital Beds Year','Hospital Beds Per 1000 People']]
hosp = hosp\
        .drop_duplicates()\
        .rename(columns = {'Hospital Beds Year':'Year'})\
        .dropna()
hosp['Year'] = hosp['Year'].astype(int)
hosp = hosp.sort_values(by=['Country','Year'], ascending=True)
display(hosp)
sns.countplot(data=hosp, x='Year', color='#2b8cbe')

# Unique country values = 173. No repeating years for countries.
len(set(hosp['Country']))

hosp.to_csv(folder + r'/hospitalbeds.csv',index=False)
# Out:
#            Country  Year  Hospital Beds Per 1000 People
# 0      Afghanistan  2015                            0.5
# 282        Albania  2013                            2.9
# 495        Algeria  2015                            1.9
# 777        Andorra  2009                            2.5
# 991         Angola  2005                            0.8
# ...            ...   ...                            ...
# 40708    Venezuela  2014                            0.8
# 40915      Vietnam  2014                            2.6
# 41197        Yemen  2014                            0.7
# 41378       Zambia  2010                            2.0
# 41581     Zimbabwe  2011                            1.7
#
# [173 rows x 3 columns]

# %% [markdown]
# # Covid data

# %%
# Subset of Covid data only
covid = data[['Date','Country'\
              ,'New_Cases','New_Deaths'\
              ,'Total_Cases','Total_Deaths'\
              ,'Weekly_Cases','Weekly_Deaths'\
              ,'RunTot_New_Cases','RunTot_New_Deaths']]
print(len(covid))

# Removed duplicates and rows where cases hadn't started recording yet (new=0)
covid = covid\
        .drop_duplicates()\
        .sort_values(by=['Country','Date'], ascending=True)
covid.drop(covid[covid['Total_Cases']==0].index, inplace=True)
display(covid)

covid.to_csv(folder + r'/covid.csv',index=False)
# Out:
# 41782
#              Date      Country  New_Cases  New_Deaths  Total_Cases  \
# 56     2020-02-25  Afghanistan        1.0         0.0          1.0
# 57     2020-02-26  Afghanistan        0.0         0.0          1.0
# 58     2020-02-27  Afghanistan        0.0         0.0          1.0
# 59     2020-02-28  Afghanistan        0.0         0.0          1.0
# 60     2020-02-29  Afghanistan        0.0         0.0          1.0
# ...           ...          ...        ...         ...          ...
# 41777  2020-10-03     Zimbabwe        8.0         0.0       7858.0
# 41778  2020-10-04     Zimbabwe       27.0         0.0       7885.0
# 41779  2020-10-05     Zimbabwe        0.0         0.0       7885.0
# 41780  2020-10-06     Zimbabwe       13.0         0.0       7898.0
# 41781  2020-10-07     Zimbabwe       17.0         1.0       7915.0
#
#        Total_Deaths  Weekly_Cases  Weekly_Deaths  RunTot_New_Cases  \
# 56              0.0           1.0            0.0                 1
# 57              0.0           1.0            0.0                 1
# 58              0.0           1.0            0.0                 1
# 59              0.0           1.0            0.0                 1
# 60              0.0           1.0            0.0                 1
# ...             ...           ...            ...               ...
# 41777         228.0          71.0            1.0              7858
# 41778         228.0          82.0            1.0              7885
# 41779         228.0          73.0            1.0              7885
# 41780         228.0          82.0            0.0              7898
# 41781         229.0          78.0            1.0              7915
#
#        RunTot_New_Deaths
# 56                     0
# 57                     0
# 58                     0
# 59                     0
# 60                     0
# ...                  ...
# 41777                228
# 41778                228
# 41779                228
# 41780                228
# 41781                229
#
# [38885 rows x 10 columns]

# %% [markdown]
# # Country data

# %%
# Subset of country data only
supp = data[data.columns[~data.columns.isin(['Hospital Beds Year','Hospital Beds Per 1000 People'\
              ,'Date'\
              ,'New_Cases','New_Deaths'\
              ,'Total_Cases','Total_Deaths'\
              ,'Weekly_Cases','Weekly_Deaths'\
              ,'RunTot_New_Cases','RunTot_New_Deaths'])]]

# Removed duplicates
supp = supp\
        .drop_duplicates()\
        .sort_values(by=['Country','Year'], ascending=True)
display(supp)

supp.to_csv(folder + r'/countries.csv',index=False)
# Out:
#            Continent      Country  Population_Density  Fertility_Rate  \
# 0               Asia  Afghanistan                59.6            4.04
# 282           Europe      Albania               105.0            1.70
# 495           Africa      Algeria                18.4            2.54
# 777           Europe      Andorra               164.0             NaN
# 991           Africa       Angola                26.4            5.41
# ...              ...          ...                 ...             ...
# 40708  South America    Venezuela                32.2            2.23
# 40915           Asia      Vietnam               314.0            1.94
# 41197           Asia        Yemen                56.5            3.61
# 41378         Africa       Zambia                24.7            4.76
# 41581         Africa     Zimbabwe                38.4            3.47
#
#        GDP_PPP  Corruption  Government_Effectiveness  Political_Stability  \
# 0       1800.0   -1.496648                 -1.457285            -2.746730
# 282    13200.0   -0.521867                  0.114788             0.382100
# 495    14000.0   -0.636465                 -0.443925            -0.793785
# 777    55000.0    1.238614                  1.944976             1.425432
# 991     5440.0   -1.144541                 -1.052086            -0.319035
# ...        ...         ...                       ...                  ...
# 40708   9050.0   -1.467512                 -1.581517            -1.343512
# 40915   7350.0   -0.485357                 -0.003445             0.203266
# 41197   2330.0   -1.637971                 -2.244354            -3.002496
# 41378   3650.0   -0.656137                 -0.559209             0.141994
# 41581   2410.0   -1.235616                 -1.198860            -0.707054
#
#        Rule_of_Law  Government_Healthcare_Spend  ...  Obesity_Rate    Year  \
# 0        -1.668478                     0.050958  ...         0.055  2019.0
# 282      -0.392243                          NaN  ...         0.217  2019.0
# 495      -0.775309                     0.659547  ...         0.274  2019.0
# 777       1.607738                     0.490320  ...         0.256  2019.0
# 991      -1.048023                     0.462786  ...         0.082  2019.0
# ...            ...                          ...  ...           ...     ...
# 40708    -2.338622                     0.159387  ...         0.256  2019.0
# 40915    -0.003282                     0.486229  ...         0.021  2019.0
# 41197    -1.790394                          NaN  ...         0.171  2019.0
# 41378    -0.344939                     0.386330  ...         0.081  2019.0
# 41581    -1.273630                     0.516158  ...         0.155  2019.0
#
#        Diabetes Prevelance % of Population 20-79  Labour Force Total  \
# 0                                            9.2          10699797.0
# 282                                          9.0           1313923.0
# 495                                          6.7          12303926.0
# 777                                          7.7                 NaN
# 991                                          4.5          13164276.0
# ...                                          ...                 ...
# 40708                                        7.0          12364879.0
# 40915                                        6.0          57364650.0
# 41197                                        5.4           6734980.0
# 41378                                        4.5           7401485.0
# 41581                                        1.8           7039493.0
#
#        Population  Population Aged 65 and above % of Total  Urban Population  \
# 0      38041754.0                                 2.615794         9797273.0
# 282     2854191.0                                14.202631         1747593.0
# 495    43053054.0                                 6.552778        31510100.0
# 777       77142.0                                      NaN           67873.0
# 991    31825295.0                                 2.199342        21061025.0
# ...           ...                                      ...               ...
# 40708  28515829.0                                 7.610990        25162368.0
# 40915  96462106.0                                 7.553673        35332140.0
# 41197  29161922.0                                 2.902141        10869523.0
# 41378  17861030.0                                 2.115315         7871713.0
# 41581  14645468.0                                 2.980608         4717305.0
#
#        Death Rate Per 1000 (2017)  \
# 0                           6.575
# 282                         7.714
# 495                         4.717
# 777                           NaN
# 991                         8.432
# ...                           ...
# 40708                       6.814
# 40915                       6.253
# 41197                       5.978
# 41378                       6.633
# 41581                       8.044
#
#        PM2.5 air pollution, mean annual exposure (micrograms per cubic meter) (2017)  \
# 0                                              56.910808
# 282                                            18.200603
# 495                                            38.884011
# 777                                            10.307621
# 991                                            32.388505
# ...                                                  ...
# 40708                                          17.008554
# 40915                                          29.626728
# 41197                                          50.456007
# 41378                                          27.438035
# 41581                                          22.251671
#
#        PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total) (2017)
# 0                                             100.000000
# 282                                           100.000000
# 495                                           100.000000
# 777                                            17.824459
# 991                                           100.000000
# ...                                                  ...
# 40708                                          99.933662
# 40915                                         100.000000
# 41197                                         100.000000
# 41378                                         100.000000
# 41581                                         100.000000
#
# [180 rows x 24 columns]

# %% [markdown]
# # Age standardised mortality rates UK

# %%
age = pd.read_excel(folder + r"/Age standardised mortality rates UK.xlsx")
#age.shape
#age.head(5)
age_unpivot = pd.melt(age, id_vars='Country')
age_unpivot = age_unpivot.rename(columns={'variable':'Date','value':'Age'})
display(age_unpivot)

age_unpivot.to_csv(folder + r'/Age standardised mortality rates UK_unpivot.csv',index=False)
# Out:
#                Country       Date        Age
# 0       United Kingdom 2019-10-07  17.709691
# 1              England 2019-10-07  17.321838
# 2                Wales 2019-10-07  17.496111
# 3             Scotland 2019-10-07  21.789274
# 4     Northern Ireland 2019-10-07  17.617802
# ...                ...        ...        ...
# 9715          Slovakia 2020-06-08        NaN
# 9716          Slovenia 2020-06-08        NaN
# 9717             Spain 2020-06-08  40.217186
# 9718            Sweden 2020-06-08  66.456393
# 9719       Switzerland 2020-06-08  49.988643
#
# [9720 rows x 3 columns]

# %% [markdown]
# # Other

# %%
#%%script false --no-raise-error
profile = ProfileReport(supp, title='Country Profiling Report', explorative=True)
profile.to_file("country_profiling_report.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=39.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
# %%script false --no-raise-error
# # Unpivot data
# datau = data.copy()
# datau = datau.reset_index()
# unpivot = pd.melt(datau, id_vars='index')
# display(unpivot)
# unpivot.to_csv(folder + r'/data unpivot.csv',index=False)
